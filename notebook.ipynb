# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import pandas as pd
import time
from datetime import datetime as dt

# %%
DRIVER = webdriver.Chrome()
copper = "https://www.coppercolorado.com/the-mountain/trail-lift-info/winter-trail-report"
DRIVER.get(copper)

# %%
for button in DRIVER.find_elements(By.XPATH, '//span[@class="panel-icon"]'):
    button.click()

# %%
def isElementPresent(driver, lookupType, locatorKey):
    try:
        driver.find_element(lookupType, locatorKey)
        return True
    except NoSuchElementException as e:
        return False

# %%
# each row within all the tables
runs = []
lifts = []
rows = DRIVER.find_elements(By.TAG_NAME, "tr")

# %%
for run in rows:
    # print(run.text)
    if isElementPresent(run, By.XPATH, ".//*[name()='td'][@class='type']"):
        #TODO
        lift_name, lift_status, lift_type = None, None, None
        lift_name = run.find_element(By.CLASS_NAME, "name").get_attribute("innerHTML")
        lift_status = isElementPresent(run, By.XPATH, ".//*[name()='path'][@fill='#8BC53F']")
        lift_type = run.find_element(By.CLASS_NAME, "type").get_attribute("innerHTML")
        
        lift_obj = {
            "Lift_Name": lift_name,
            "Lift_Type": lift_type,
            "Lift_Status": lift_status,
        }
        lifts.append(lift_obj)

    else:
        # reset vars
        run_name, run_status, run_difficulty = None, None, None

        run_name = run.find_element(By.CLASS_NAME, "name").get_attribute("innerHTML")
        run_status = isElementPresent(run, By.XPATH, ".//*[name()='path'][@fill='#8BC53F']") 
        try:
            difficulty_text = run.find_element(By.CLASS_NAME, "difficulty").find_element(By.TAG_NAME, "div").get_attribute("class")
            if "icon difficulty-level-green" in difficulty_text: run_difficulty = "green"
            elif "icon difficulty-level-blue" in difficulty_text: run_difficulty = "blue"
            elif "icon difficulty-level-black-3" in difficulty_text: run_difficulty = "black3"
            elif "icon difficulty-level-black-2" in difficulty_text: run_difficulty = "black2"
            elif "icon difficulty-level-black" in difficulty_text: run_difficulty = "black1"
            
        except NoSuchElementException as e:
            print("unable to find difficulty")
        run_obj = {
            "Run_Name": run_name,
            "Run_Status": run_status,
            "Run_Difficulty": run_difficulty,
        }
        runs.append(run_obj)
# Out:
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty
# unable to find difficulty

# %%
print(lifts)
print(runs)

lifts_set = {each['Lift_Name'] : each for each in lifts}.values()
lifts_set

runs_set = {each['Run_Name'] : each for each in runs}.values()
runs_set

now = dt.today()
formatted = now.strftime("%Y-%m-%d")
formatted
# Out:
# [{'Lift_Name': 'American Eagle', 'Lift_Type': 'Telemix', 'Lift_Status': True}, {'Lift_Name': 'American Flyer', 'Lift_Type': 'Six Person', 'Lift_Status': True}, {'Lift_Name': 'Excelerator', 'Lift_Type': 'Quad', 'Lift_Status': True}, {'Lift_Name': 'Kokomo Express', 'Lift_Type': 'Quad', 'Lift_Status': True}, {'Lift_Name': 'Lumberjack', 'Lift_Type': 'Triple', 'Lift_Status': False}, {'Lift_Name': 'Rugrat', 'Lift_Type': 'Carpet', 'Lift_Status': True}, {'Lift_Name': 'Slingshot/Glide', 'Lift_Type': 'Carpet', 'Lift_Status': True}, {'Lift_Name': 'Timberline Express', 'Lift_Type': 'Six Person', 'Lift_Status': True}, {'Lift_Name': 'Woodward Express', 'Lift_Type': 'Quad', 'Lift_Status': True}, {'Lift_Name': 'Alpine', 'Lift_Type': 'Double', 'Lift_Status': True}, {'Lift_Name': 'Tubing Hill', 'Lift_Type': 'Carpet', 'Lift_Status': True}, {'Lift_Name': 'Super Bee', 'Lift_Type': 'Six Person', 'Lift_Status': True}, {'Lift_Name': 'Easy Rider', 'Lift_Type': 'Carpet', 'Lift_Status': True}, {'Lift_Name': 'Gem', 'Lift_Type': 'Surface', 'Lift_Status': True}, {'Lift_Name': 'Pitchfork', 'Lift_Type': 'Double', 'Lift_Status': True}, {'Lift_Name': 'Celebrity Ridge', 'Lift_Type': 'Surface', 'Lift_Status': True}, {'Lift_Name': 'Rendezvous', 'Lift_Type': 'Triple', 'Lift_Status': True}, {'Lift_Name': 'Sierra', 'Lift_Type': 'Triple', 'Lift_Status': True}, {'Lift_Name': 'Resolution', 'Lift_Type': 'Triple', 'Lift_Status': True}, {'Lift_Name': 'Storm King', 'Lift_Type': 'Surface', 'Lift_Status': True}, {'Lift_Name': 'Three Bears', 'Lift_Type': 'Triple', 'Lift_Status': True}, {'Lift_Name': 'Black Jack', 'Lift_Type': 'Double', 'Lift_Status': True}, {'Lift_Name': 'Mountain Chief', 'Lift_Type': 'Double', 'Lift_Status': True}, {'Lift_Name': 'American Eagle', 'Lift_Type': 'Telemix', 'Lift_Status': True}, {'Lift_Name': 'American Flyer', 'Lift_Type': 'Six Person', 'Lift_Status': True}, {'Lift_Name': 'Excelerator', 'Lift_Type': 'Quad', 'Lift_Status': True}, {'Lift_Name': 'Kokomo Express', 'Lift_Type': 'Quad', 'Lift_Status': True}, {'Lift_Name': 'Lumberjack', 'Lift_Type': 'Triple', 'Lift_Status': False}, {'Lift_Name': 'Rugrat', 'Lift_Type': 'Carpet', 'Lift_Status': True}, {'Lift_Name': 'Slingshot/Glide', 'Lift_Type': 'Carpet', 'Lift_Status': True}, {'Lift_Name': 'Timberline Express', 'Lift_Type': 'Six Person', 'Lift_Status': True}, {'Lift_Name': 'Woodward Express', 'Lift_Type': 'Quad', 'Lift_Status': True}, {'Lift_Name': 'Alpine', 'Lift_Type': 'Double', 'Lift_Status': True}, {'Lift_Name': 'Tubing Hill', 'Lift_Type': 'Carpet', 'Lift_Status': True}, {'Lift_Name': 'Super Bee', 'Lift_Type': 'Six Person', 'Lift_Status': True}, {'Lift_Name': 'Easy Rider', 'Lift_Type': 'Carpet', 'Lift_Status': True}, {'Lift_Name': 'Gem', 'Lift_Type': 'Surface', 'Lift_Status': True}, {'Lift_Name': 'Pitchfork', 'Lift_Type': 'Double', 'Lift_Status': True}, {'Lift_Name': 'Celebrity Ridge', 'Lift_Type': 'Surface', 'Lift_Status': True}, {'Lift_Name': 'Rendezvous', 'Lift_Type': 'Triple', 'Lift_Status': True}, {'Lift_Name': 'Sierra', 'Lift_Type': 'Triple', 'Lift_Status': True}, {'Lift_Name': 'Resolution', 'Lift_Type': 'Triple', 'Lift_Status': True}, {'Lift_Name': 'Storm King', 'Lift_Type': 'Surface', 'Lift_Status': True}, {'Lift_Name': 'Three Bears', 'Lift_Type': 'Triple', 'Lift_Status': True}, {'Lift_Name': 'Black Jack', 'Lift_Type': 'Double', 'Lift_Status': True}, {'Lift_Name': 'Mountain Chief', 'Lift_Type': 'Double', 'Lift_Status': True}]
# [{'Run_Name': 'Lift Name', 'Run_Status': False, 'Run_Difficulty': None}, {'Run_Name': 'Lift Name', 'Run_Status': False, 'Run_Difficulty': None}, {'Run_Name': 'Trail Name', 'Run_Status': False, 'Run_Difficulty': None}, {'Run_Name': '17 Glade', 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'American Flyer', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Bittersweet (L)', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Bittersweet (U)', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Bouncer (L)', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Bouncer (U)', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': "Brennan's Grin", 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'Bridgeway', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': "CDL's Trail #20", 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'Cache Glades', 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'Carefree (L)', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Carefree (U)', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'Collage (L)', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Collage (U)', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Copperopolis', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Coppertone', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'Easy Road', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'Easy Road Traverse', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'Fair Play', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Family Cross', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'Foul Play', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': "Frank's Fave", 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Hallelujah', 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'High Point', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'High Point Bypass', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'I-Dropper', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Indian Ridge', 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'Leap Frog (L)', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'Leap Frog (U)', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'Liberty', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Looking Glass', 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'Loverly', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'Lower Enchanted Forest', 'Run_Status': True, 'Run_Difficulty': 'black2'}, {'Run_Name': 'Main Vein', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Mine Dump', 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'Nastar', 'Run_Status': False, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Ptarmigan', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Rhapsody', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Sail Away Glades', 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'See and Ski', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'Skid Road', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Slip Not', 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'Sluice', 'Run_Status': True, 'Run_Difficulty': 'green'}, {'Run_Name': 'Upper Looking Glass', 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'Upper Sluice', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Ute Overlook', 'Run_Status': True, 'Run_Difficulty': 'black1'}, {'Run_Name': 'Lift Name', 'Run_Status': False, 'Run_Difficulty': None}, {'Run_Name': 'Trail Name', 'Run_Status': False, 'Run_Difficulty': None}, {'Run_Name': 'Bucksaw', 'Run_Status': True, 'Run_Difficulty': 'blue'}, {'Run_Name': 'Clear Cut', 'Run_Status': True, 'Run_Dif ...
# '2025-01-08'

# %%
df_runs = pd.json_normalize(runs_set)
df_runs['Updated_Date'] = formatted
df_runs
# Out:
#             Run_Name  Run_Status Run_Difficulty Updated_Date
# 0          Lift Name       False           None   2025-01-08
# 1         Trail Name       False           None   2025-01-08
# 2           17 Glade        True         black1   2025-01-08
# 3     American Flyer        True           blue   2025-01-08
# 4    Bittersweet (L)        True           blue   2025-01-08
# ..               ...         ...            ...          ...
# 157        Matchless        True         black1   2025-01-08
# 158        Otto Bahn        True           blue   2025-01-08
# 159          Rattler        True         black1   2025-01-08
# 160       Schaefer's        True         black3   2025-01-08
# 161      Six Shooter        True         black1   2025-01-08
#
# [162 rows x 4 columns]

# %%
df_lifts = pd.json_normalize(lifts_set)
df_lifts['Updated_Date'] = formatted
df_lifts
# Out:
#              Lift_Name   Lift_Type  Lift_Status Updated_Date
# 0       American Eagle     Telemix         True   2025-01-08
# 1       American Flyer  Six Person         True   2025-01-08
# 2          Excelerator        Quad         True   2025-01-08
# 3       Kokomo Express        Quad         True   2025-01-08
# 4           Lumberjack      Triple        False   2025-01-08
# 5               Rugrat      Carpet         True   2025-01-08
# 6      Slingshot/Glide      Carpet         True   2025-01-08
# 7   Timberline Express  Six Person         True   2025-01-08
# 8     Woodward Express        Quad         True   2025-01-08
# 9               Alpine      Double         True   2025-01-08
# 10         Tubing Hill      Carpet         True   2025-01-08
# 11           Super Bee  Six Person         True   2025-01-08
# 12          Easy Rider      Carpet         True   2025-01-08
# 13                 Gem     Surface         True   2025-01-08
# 14           Pitchfork      Double         True   2025-01-08
# 15     Celebrity Ridge     Surface         True   2025-01-08
# 16          Rendezvous      Triple         True   2025-01-08
# 17              Sierra      Triple         True   2025-01-08
# 18          Resolution      Triple         True   2025-01-08
# 19          Storm King     Surface         True   2025-01-08
# 20         Three Bears      Triple         True   2025-01-08
# 21          Black Jack      Double         True   2025-01-08
# 22      Mountain Chief      Double         True   2025-01-08
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
